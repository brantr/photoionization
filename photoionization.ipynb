# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import numpy as np
from array_io import *

# %%
fname = "pi.txt"
E,sigma_HI,sigma_HeI,sigma_HeII = read_four_arrays(fname)

# %%
fig = plt.figure(figsize=(10,10))
plt.xlim([10,100])
plt.xscale('log')
plt.yscale('log')
plt.plot(E,sigma_HI,color="red")
plt.plot(E,sigma_HeI,color="blue")
plt.plot(E,sigma_HeII,color="green")
plt.plot(E,6.3e-18 * (E/13.6)**-3,color="black",linestyle=":")
